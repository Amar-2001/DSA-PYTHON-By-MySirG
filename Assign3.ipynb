# %%
# Question last or Iterator

# Question 11. Delete particular  item


class Node:
    def __init__(self, item=None, next=None):
        self.item=item
        self.next=next
        
class SLL:
    def __init__(self,start=None):
        self.start=start
        
    def is_empty(self):
        return self.start==None # agar start mein kuch nahi toh return kar do list empty hai 
    
    
    def insert_at_start(self, data):
        n=Node(data,self.start) # Yaha Node class ko call kiya gaya n object ke dwara aur 
                        # usme(n mein) data aur start(self ke jariye start ) pass kiya gaya
                        # ya simply node ko call kiya gaya aur usme data daal diya gaya 
        self.start=n  # start node mein n (jo ki ek new node hai jisme data aur address hai) jod do 
                
            # doubt 1. clear :-  when multiple node are present:-
             #  agar kayi node present huwe tab  
                # n yaani new node ke next mein start ka address aa jaaye 
                # jo ki pehle apne next node ko point kar raha hota tab n ke next mein jo pehle start ke 
                # next mein tha wo aa jaayega toh next node usse connect ho gaya ok
                
                # doubt 2 clear :- when node is empty
                 # agar node empty bhi hua toh n yaani new  node ke next mein start aa jaayega jo ki
         # start  pehle null tha means ab node ke next mein bhi null ho jayega toh bhi koi dikkat nahi 
                    
    
    def insert_at_last(self):
        n=Node(data) # simply :- node create kiye usme data daale ya Node object ko call kiye  
                 # usme (data) pass kiye ya argument diye aur usko n object ke call kiye ya n mein store kiye
        
        if not self.is_empty(): # agar node empty nahi hai toh 
            temp=self.start # temporary variable mein start ki value daal do jiss se wo pehla node 
                             # ko point karega and then all by traversing when(temp.next) is used
            while temp.next is not None: # agar temp.Next none nahi aata
                temp=temp.next
            temp.next=n # agar temp ke next mein None aa gaya toh temp ke next mein new node(n) add karte
          
        else:
            self.start=n # agar node empty hua toh start ke andar new node(n) add kar do
      
    
    
    def search(self,data): # kisi element(data) ko hi finnd karna hai that's why 1 argument
        temp=self.start # temp ke andar start ki value whatever start ke baad node ho na ho doesn't matter
        while temp is not None: # jab tak node empty na ho ya temp ke next mein None na ho toh tab tak
            if temp.item==data: # agar temp ke item mein jo element hai wo data element se match kar jata toh
                return temp   # return kar do temp variable ko (return means ab toh function end ho hi Jayega)
            temp=temp.next # agar nahi mila toh next node mein check karo until element is matched
            # (That's why temp while loop ke andar hai)
        return None # Agar data kisi se match nahi kiya last element tak node kuch return nahi kar payega then
                  # return kar do None means element nahi mila 
    
    
    
    def insert_after(self,temp,data): # 3 argument:- kya data insert karna hai , i
                                       # dursra kis node ke baad data enter karna ha aur self toh hoga hi
        if temp is not None: # agar temp none nahi hai means list empty nahi hai 
            n=Node(data,temp.next)  # simply :- node create karo ya bol sakte hai n object ke andar Node ko call kiya gaya 
                                    # aur usme data aur temp ka next rakhe 
            temp.next=n   # temp ke next mein new node(n) add kar denge 
    
    
    # Solution Here
    def print_list(self): # no argument only self kyunki kuch item insert nahi karna sirf print karna that's why
        temp=self.start  # temp ke andar start ka reference(pointer) daal diye
        while temp is not None: # jab tak temp none na ho ya list empty na ho tab tak chalta rahe
            print(temp.item,end = " ")  # aur print karta rahe temp ke item ke andar jo value hai usko
            temp=temp.next
        
    
    def delete_first(self):
        if self.start is not None: # agar list empty nahi hai toh 
            self.start=self.start.next # start mein start ke next daal d
            
            
     
    def delete_last(self):
        if self.start is None: # agar list empty hai toh pass karo yaani function sirf chala do 
            pass
         
        #agar list mein ek hi node ho toh
        elif self.start.next is None: # agar list empty nahi hai ya start ke next None nahi hai means 
                                      # uske aage bhi element hoga means wo last ke just ek node pehle ki baat ho rahi
            self.start=None
            
            #agar list mein multiple node ho tab
        else:
            temp=self.start
            while temp.next.next is not None:
                temp=temp.next
            temp.next=None
    
    
    # solution here
    
    def delete_item(self,data):# kisko delete karna chahte ho
        if self.start is None: # agar node empty nahi hai yaani start none hai tab
            pass  # pass  kar do
        
        # agar start ka next none hai yaani list mein ek hi node ho tab
        elif self.start.next is None:
            if self.start.item==data: # agar start ke item agar data ke barabaar hua 
                self.start=None # toh start mein none rakh do means ab toh list empty/delete  ho gaya
                
             # Agar multiple node ho toh   
        else:
            temp=self.start  # temp mein start rakho
             
                # agar pehla node ko hi delete karna pada toh
            if temp.item==data: # temp ka item aur data match karta tab 
                self.start=temp.next # start mein temp ka next yani next node ka address start mein rakh do
               # jisse start ke aage wala node start mein aa jaaye aur pehla node delete  ho jaaye
            
            # nahi toh 
            else: # nahi toh 
                while temp.next is not None: #jab tak temp ka next mein none nahi aata  yaani last node tak check karega
                    if temp.next.item==data: # agar temp ka next ka item data se match karta toh 
                        temp.next=temp.next.next # temp ka next mein temp ka next ka bhi next rakh do yaaani agla node ka reference
                        break # aur loop break kar kaam hone par yaani agar temp next ke item mein 
                                    # data mil jaaye toh usko delete karo aur loop se exit ho 
                            
                    # nahi toh aage badh kar check karo ki temp ke next ke item aur data equal hai ya nahi 
                    temp=temp.next # chalate raho while loop ko jab tak temp ka next ka item aur data equal na ho jaye
                    
                    
# # solution here
        
    def __iter__(self): # ek function banao __iter__ tabhi iterable banega
        return SLLIterator(self.start) # aur SLLIterator ko return kar do start se  (start upar wala start hai yaani shuru se list ko chala do end tak)
    
class SLLIterator: # pehle class iterable banana hoga 
    def __init__(self,start): # phir function start se shrur karenge
        self.current=start # current mein start rakh denge # current work as temp jaise kaam karta tha
        
    def __iter__(self): # phir __iter__ banayenge
        return self      # self return karayenge 
    
    def __next__(self): # phir next 
        if not self.current: # agar nahi hai current mein 
            raise StopIteration # iteration rok do message aa jaye ye exception handling mein padha tha na
        data=self.current.item  # current ke item  ko data mein rakh do (just like temp ke item ko)
        self.current=self.current.next  # current mein current ka next(just like temp mein temp.next)
        return data
        
 

 # driver code # driver code ko hide kiye thodi der ke liye for assignment 11 or Stak by 
# importing Singly link list and Stack by inheriting and importing singly link list 
mylist=SLL()
mylist.insert_at_start(10)
mylist.insert_at_start(20) # also work but 20 start mein aa jayega becuase tum usko start mein add kiye
                            # output 20 10
# mylist.insert_after(10,20) # error 
mylist.insert_after(mylist.search(10),15)
mylist.insert_after(mylist.search(15),153)
mylist.insert_after(mylist.search(10),18)
mylist.delete_first()
mylist.delete_last()
mylist.delete_item(10)
mylist.print_list()

# To access through iterables 
# for x in mylist:
#     print(x,end=" ")
# 'SLL' object is not iterable 
# kuch chize iterable hoti hai like list,tuple ,range etc
# but kuch chize iterable nahi hoti like int , obj etc
# to make it iterable we use iterator concept 

print()
for x in mylist:
    print(x,end=" ")
# Out:
# 18 15
# 18 15
