# %%
# 1. Queue define by Singly Link list

class Node:
    def __init__(self,item=None,next=None):
        self.item=item
        self.next=next

class Queue:
    def __init__(self):
        self.front=None
        self.rear=None

# %%
# 2. is_emtpy()

class Node:
    def __init__(self,item=None,next=None):
        self.item=item
        self.next=next

class Queue:
    def __init__(self):
        self.front=None
        self.rear=None
        self.item_count=0
        
    def is_empty(self):
        return self.front==None
        # return self.rear==None
        # return self.item_count==0

# %%
# 3 Enqueue

class Node:
    def __init__(self,item=None,next=None):
        self.item=item
        self.next=next

class Queue:
    def __init__(self):
        self.front=None
        self.rear=None
        self.item_count=0
        
    def is_empty(self):
        return self.front==None
        # return self.rear==None
        # return self.item_count==0
    
    def enqueue(self,data):
        n=Node(data)
        if self.is_empty():
            self.front=n
            # self.rear=n # jab node empty ho ya multiple nodes ho tab bhi rear mein "n" judega 
        else:
            self.rear.next=n
        self.rear=n
        self.item_count+=1

# %%
# 4.Dequeue

# 3 Enqueue

class Node:
    def __init__(self,item=None,next=None):
        self.item=item
        self.next=next

class Queue:
    def __init__(self):
        self.front=None
        self.rear=None
        self.item_count=0
        
    def is_empty(self):
        return self.front==None
        # return self.rear==None
        # return self.item_count==0
    
    def enqueue(self,data):
        n=Node(data)
        if self.is_empty():
            self.front=n
            # self.rear=n # jab node empty ho ya multiple nodes ho tab bhi rear mein "n" judega 
        else:
            self.rear.next=n
        self.rear=n
        self.item_count+=1
    
    def dequeue(self):
        # agar queue ki list empty hai tab
        if self.is_empty():
            raise IndexError("Queue is empty")
        # agar ek hi node ho tab
        elif self.front==self.rear:
            self.front=None
            self.rear=None
        # agar multiple nodes ho tab
        else:
            self.front=self.front.next
        
        self.item_count-=1

# %%
# 5.get_front

# 4.Dequeue

# 3 Enqueue

class Node:
    def __init__(self,item=None,next=None):
        self.item=item
        self.next=next

class Queue:
    def __init__(self):
        self.front=None
        self.rear=None
        self.item_count=0
        
    def is_empty(self):
        return self.front==None
        # return self.rear==None
        # return self.item_count==0
    
    def enqueue(self,data):
        n=Node(data)
        if self.is_empty():
            self.front=n
            # self.rear=n # jab node empty ho ya multiple nodes ho tab bhi rear mein "n" judega 
        else:
            self.rear.next=n
        self.rear=n
        self.item_count+=1
    
    def dequeue(self):
        # agar queue ki list empty hai tab
        if self.is_empty():
            raise IndexError("Queue is empty")
        # agar ek hi node ho tab
        elif self.front==self.rear:
            self.front=None
            self.rear=None
        # agar multiple nodes ho tab
        else:
            self.front=self.front.next
        
        self.item_count-=1
        
        def get_front(self):
            if self.is_emtpy():
                raise IndexError("Queue is empty")
            else:
                return self.rear.item

# %%
# 5.get_rear

class Node:
    def __init__(self,item=None,next=None):
        self.item=item
        self.next=next

class Queue:
    def __init__(self):
        self.front=None
        self.rear=None
        self.item_count=0
        
    def is_empty(self):
        return self.front==None
        # return self.rear==None
        # return self.item_count==0
    
    def enqueue(self,data):
        n=Node(data)
        if self.is_empty():
            self.front=n
            # self.rear=n # jab node empty ho ya multiple nodes ho tab bhi rear mein "n" judega 
        else:
            self.rear.next=n
        self.rear=n
        self.item_count+=1
    
    def dequeue(self):
        # agar queue ki list empty hai tab
        if self.is_empty():
            raise IndexError("Queue is empty")
        # agar ek hi node ho tab
        elif self.front==self.rear:
            self.front=None
            self.rear=None
        # agar multiple nodes ho tab
        else:
            self.front=self.front.next
        
        self.item_count-=1
        
        def get_front(self):
            if self.is_emtpy():
                raise IndexError("Queue is empty")
            else:
                return self.front.item
        
        def get_rear(self):
            if self.is_emtpy():
                raise IndexError("Queue is empty")
            else:
                return self.front.item

# %%
# size

class Node:
    def __init__(self,item=None,next=None):
        self.item=item
        self.next=next

class Queue:
    def __init__(self):
        self.front=None
        self.rear=None
        self.item_count=0
        
    def is_empty(self):
        return self.front==None
        # return self.rear==None
        # return self.item_count==0
    
    def enqueue(self,data):
        n=Node(data)
        if self.is_empty():
            self.front=n
            # self.rear=n # jab node empty ho ya multiple nodes ho tab bhi rear mein "n" judega 
        else:
            self.rear.next=n
        self.rear=n
        self.item_count+=1
    
    def dequeue(self):
        # agar queue ki list empty hai tab
        if self.is_empty():
            raise IndexError("Queue is empty")
        # agar ek hi node ho tab
        elif self.front==self.rear:
            self.front=None
            self.rear=None
        # agar multiple nodes ho tab
        else:
            self.front=self.front.next
        
        self.item_count-=1
        
    def get_front(self):
        if self.is_empty():
            raise IndexError("Queue is empty")
        else:
            return self.front.item
        
    def get_rear(self):
        if self.is_empty():
            raise IndexError("Queue is empty")
        else:
            return self.rear.item
            
    def size(self):
        return self.item_count
        
# driver code
q1=Queue()
q1.enqueue(10)
q1.enqueue(20)
q1.enqueue(30)
print("Front :",q1.get_front()," Rear :",q1.get_rear())
q1.dequeue()
print("Front :",q1.get_front()," Rear :",q1.get_rear())
q1.enqueue()
print("Front :",q1.get_front()," Rear :",q1.get_rear())
# Out:
# Front : 10  Rear : 30
# Front : 20  Rear : 30
# Front : 30  Rear : 30

# %%
5
# Out:
# 5

# %%
# Professional log mostly practice nahi karte hai isliye sahi se nahi seekh paate mostly 30-40 years ke log
