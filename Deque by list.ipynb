# %%
class Deque:
    def __init__(self):
        self.item=[]

# %%
class Deque:
    def __init__(self):
        self.item=[]
    
    def is_empty(self):
        return len(self.item)==0

# %%
class Deque:
    def __init__(self):
        self.item=[]
    
    def is_empty(self):
        return len(self.item)==0
    
    def insert_front(self,data):
        self.item.insert(0)

# %%
class Deque:
    def __init__(self):
        self.item=[]
    
    def is_empty(self):
        return len(self.item)==0
    
    def insert_front(self,data):
        self.item.insert(0,data) # insert kisi position par data daalta hai
        
    def insert_rear(self,data):
        self.item.append(data) # append last position par data daalta hai

# %%
class Deque:
    def __init__(self):
        self.item=[]
    
    def is_empty(self):
        return len(self.item)==0
    
    def insert_front(self,data):
        self.item.insert(0,data) # insert kisi position par data daalta hai
        
    def insert_rear(self,data):
        self.item.append(data) # append last position par data daalta hai
        
    def delete_front(self):
        return self.item.pop(0)

# %%
class Deque:
    def __init__(self):
        self.item=[]
    
    def is_empty(self):
        return len(self.item)==0
    
    def insert_front(self,data):
        self.item.insert(0,data) # insert kisi position par data daalta hai
        
    def insert_rear(self,data):
        self.item.append(data) # append last position par data daalta hai
        
    def delete_front(self):
        if self.is_empty():
            raise IndexError("Deque is empty")
        else:
            return self.item.pop(0)
    
    def delete_rear(self):
        if self.is_empty():
            raise IndexError("Deque is empty")
        else:
            return self.item.pop()

# %%
class Deque:
    def __init__(self):
        self.item=[]
    
    def is_empty(self):
        return len(self.item)==0
    
    def insert_front(self,data):
        self.item.insert(0,data) # insert kisi position par data daalta hai
        
    def insert_rear(self,data):
        self.item.append(data) # append last position par data daalta hai
        
    def delete_front(self):
        if self.is_empty():
            raise IndexError("Deque is empty")
        else:
            return self.item.pop(0)
    
    def delete_rear(self):
        if self.is_empty():
            raise IndexError("Deque is empty")
        else:
            return self.item.pop()
        
    def get_front(self):
        if self.is_empty():
            raise IndexError("Deque is empty")
        else:
            return self.item[-1]

# %%
class Deque:
    def __init__(self):
        self.item=[]
    
    def is_empty(self):
        return len(self.item)==0
    
    def insert_front(self,data):
        self.item.insert(0,data) # insert kisi position par data daalta hai
        
    def insert_rear(self,data):
        self.item.append(data) # append last position par data daalta hai
        
    def delete_front(self):
        if self.is_empty():
            raise IndexError("Deque is empty")
        else:
            return self.item.pop(0)
    
    def delete_rear(self):
        if self.is_empty():
            raise IndexError("Deque is empty")
        else:
            return self.item.pop()
        
    def get_front(self):
        if self.is_empty():
            raise IndexError("Deque is empty")
        else:
            return self.item[-1]
        
    def get_rear(self):
        if self.is_empty():
            raise IndexError("Deque is empty")
        else:
            return self.item[0]

# %%
class Deque:
    def __init__(self):
        self.item=[]
    
    def is_empty(self):
        return len(self.item)==0
    
    def insert_front(self,data):
        self.item.insert(0,data) # insert kisi position par data daalta hai
        
    def insert_rear(self,data):
        self.item.append(data) # append last position par data daalta hai
        
    def delete_front(self):
        if self.is_empty():
            raise IndexError("Deque is empty")
        else:
            return self.item.pop(0)
    
    def delete_rear(self):
        if self.is_empty():
            raise IndexError("Deque is empty")
        else:
            return self.item.pop()
        
    def get_front(self):
        if self.is_empty():
            raise IndexError("Deque is empty")
        else:
            return self.item[-1]
        
    def get_rear(self):
        if self.is_empty():
            raise IndexError("Deque is empty")
        else:
            return self.item[0]
        
    def size(self):
        return len(self.item)
    
d1=Deque()
d1.insert_front(10)
d1.insert_front(20)
d1.insert_rear(30)
d1.insert_rear(40)
print(d1.get_rear(),d1.get_front())
d1.delete_front()
d1.delete_rear()
print(d1.get_rear(),d1.get_front())
# Out:
# 20 40
# 10 30

# %%
# consistent ke liye daily dopamine milna chahiye 
# Overthinking ko door karne ka tarika turant action lo
