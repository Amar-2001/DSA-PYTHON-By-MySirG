# %%
class Queue:
    def __inti__(self):
        self.item=[]

# %%
# 2.

class Queue:
    def __inti__(self):
        self.item=[]
        
    def is_empty(self):
        return len(self.item)==0

# %%
# 3.

class Queue:
    def __inti__(self):
        self.item=[]
        
    def is_empty(self):
        return len(self.item)==0
    
    def enqueue(self,data):
        self.item.append()

# %%
# 4. Dequeue

# 3.

class Queue:
    def __inti__(self):
        self.item=[]
        
    def is_empty(self):
        return len(self.item)==0
    
    def enqueue(self,data):
        self.item.append()
        
    def dequeue(self):
        if not self.is_empty():
            self.item.pop(0)
        else:
            raise IndexError("Queue Underflow")

# %%
# 5. get_front

class Queue:
    def __inti__(self):
        self.item=[]
        
    def is_empty(self):
        return len(self.item)==0
    
    def enqueue(self,data):
        self.item.append()
        
    def dequeue(self):
        if not self.is_empty():
            return self.item.pop(0)
        else:
            raise IndexError("Queue Underflow")
            
    def get_front(self):
        if not self.is_empty():
            return self.item(-1)
        else:
            raise IndexError("Queue Underflow")

# %%
# 6. get_rear

class Queue:
    def __inti__(self):
        self.item=[]
        
    def is_empty(self):
        return len(self.item)==0
    
    def enqueue(self,data):
        self.item.append()
        
    def dequeue(self):
        if not self.is_empty():
            return self.item.pop(0)
        else:
            raise IndexError("Queue Underflow")
            
    def get_front(self):
        if not self.is_empty():
            return self.item(-1)
        else:
            raise IndexError("Queue Underflow")

    def get_rear(self):
        if not self.is_empty():
            return self.item(0)
        else:
            raise IndexError("Queue Underflow")

# %%
# 7.size

class Queue:
    def __inti__(self):
        self.item=[]
        
    def is_empty(self):
        return len(self.item)==0
    
    def enqueue(self,data):
        self.item.append()
        
    def dequeue(self):
        if not self.is_empty():
            return self.item.pop(0)
        else:
            raise IndexError("Queue Underflow")
            
    def get_front(self):
        if not self.is_empty():
            return self.item(-1)
        else:
            raise IndexError("Queue Underflow")

    def get_rear(self):
        if not self.is_empty():
            return self.item(0)
        else:
            raise IndexError("Queue Underflow")
            
    def size(self):
        return len(self.item)

# %%
# Driver code

# 7.size

class Queue:
    def __init__(self):
        self.item=[]
        
    def is_empty(self):
        return len(self.item)==0
    
    def enqueue(self,data):
        self.item.append()
        
    def dequeue(self):
        if not self.is_empty():
            return self.item.pop(0)
        else:
            raise IndexError("Queue Underflow")
            
    def get_front(self):
        if not self.is_empty():
            return self.item(-1)
        else:
            raise IndexError("Queue Underflow")

    def get_rear(self):
        if not self.is_empty():
            return self.item(0)
        else:
            raise IndexError("Queue Underflow")
            
    def size(self):
        return len(self.item)
    
q1=Queue()
q1.get_front() # iske aage ka code hi nahi chalega becuase python mein kisi bhi line mein error aane ke baad
                # uske aage wala line nahi chalta so we have to solve this error

q1.enqueue(10)
q1.enqueue(20)
q1.enqueue(30)
q1.enqueue(40)
q1.enqueue(50)
q1.get_front()

# our code run successfull but message print in error 
# To solve this see below
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[21], line 37
#      34         return len(self.item)
#      36 q1=Queue()
# ---> 37 q1.get_front() # iske aage ka code hi nahi chalega becuase python mein kisi bhi line mein error aane ke baad
#      38                 # uske aage wala line nahi chalta so we have to solve this error
#      40 q1.enqueue(10)
#
# Cell In[21], line 25, in Queue.get_front(self)
#      23     return self.item(-1)
#      24 else:
# ---> 25     raise IndexError("Queue Underflow")
#
# IndexError: Queue Underflow

# %%
# Driver code

# 7.size

class Queue:
    def __init__(self):
        self.item=[]
        
    def is_empty(self):
        return len(self.item)==0
    
    def enqueue(self,data):
        self.item.append(data)
        
    def dequeue(self):
        if not self.is_empty():
            return self.item.pop(0)
        else:
            raise IndexError("Queue Underflow")
            
    def get_front(self):
        if not self.is_empty():
            return self.item[-1]
        else:
            raise IndexError("Queue Underflow")

    def get_rear(self):
        if not self.is_empty():
            return self.item[0]
        else:
            raise IndexError("Queue Underflow")
            
    def size(self):
        return len(self.item)
    
q1=Queue()
try:
    q1.get_front()
except:
    print("Underflow")
q1.enqueue(10)
q1.enqueue(20)
q1.enqueue(30)
q1.enqueue(40)
q1.enqueue(50)
print("Front element :",q1.get_front(), " Rear Element :",q1.get_rear())
q1.dequeue()
print("Front element :",q1.get_front(), " Rear Element :",q1.get_rear())
print("Size of Queue :",q1.size())

q1.enqueue(60)
print("Front element :",q1.get_front(), " Rear Element :",q1.get_rear())
print("Size of Queue :",q1.size())
# Out:
# Underflow
# Front element : 50  Rear Element : 10
# Front element : 50  Rear Element : 20
# Size of Queue : 4
# Front element : 60  Rear Element : 20
# Size of Queue : 5

# %%
# Driver code

# 7.size

class Queue:
    def __init__(self):
        self.item=[]
        
    def is_empty(self):
        return len(self.item)==0
    
    def enqueue(self,data):
        self.item.append(data)
        
    def dequeue(self):
        if not self.is_empty():
            return self.item.pop(0)
        else:
            raise IndexError("Queue Underflow")
            
    def get_front(self):
        if not self.is_empty():
            return self.item[-1]
        else:
            raise IndexError("Queue Underflow")

    def get_rear(self):
        if not self.is_empty():
            return self.item[0]
        else:
            raise IndexError("Queue Underflow")
            
    def size(self):
        return len(self.item)
    
q1=Queue()
try:
    print(q1.get_front())
except IndexError as e:
    print(e.args[0])
    # print("Underflow")
q1.enqueue(10)
q1.enqueue(20)
q1.enqueue(30)
q1.enqueue(40)
q1.enqueue(50)
print("Front element :",q1.get_front(), " Rear Element :",q1.get_rear())

try:
    q1.dequeue()
    print("Queue has now size :",q1.size())
except IndexError as e:
    print(e.args[0])
print("Front element :",q1.get_front(), " Rear Element :",q1.get_rear())
print("Size of Queue :",q1.size())

q1.enqueue(60)
print("Front element :",q1.get_front(), " Rear Element :",q1.get_rear())
print("Size of Queue :",q1.size())
# Out:
# Queue Underflow
# Front element : 50  Rear Element : 10
# Queue has now size : 4
# Front element : 50  Rear Element : 20
# Size of Queue : 4
# Front element : 60  Rear Element : 20
# Size of Queue : 5
