# %%
# Doubly Link List

# %%
# 1. Create a class node of Doubly link list

# solution here
class Node:
    def __init__(self,prev,item,next):
        self.prev=prev
        self.item=item
        self.next=next

# %%
# 2. create a class DLL  with __init__ and initialise start reference variable

class Node:
    def __init__(self,prev,item,next):
        self.prev=prev
        self.item=item
        self.next=next

# Solution here
class DLL:
    def __init__(self,start=None):
        self.start=start

# %%
# 3. Create is empyt function to check list is empty or not

class Node:
    def __init__(self,prev,item,next):
        self.prev=prev
        self.item=item
        self.next=next
        

class DLL:
    def __init__(self,start=None):
        self.start=start
    
    # solution here
    def is_empty(self):
        return self.start==None # agar start mein none hai toh return karo  empty

# %%
# 4.Insert at start


class Node:
    def __init__(self,prev,item,next):
        self.prev=prev
        self.item=item
        self.next=next
        
# Now class DLL
class DLL:
    def __init__(self,start=None):
        self.start=start
     
    
    def is_empty(self):
        return self.start==None # agar start mein none hai toh return karo  empty
    
    
    # solution Here
    def insert_at_start(self,data):
        n=Node(None,data,self.start)# prev mein none , item mein data aur next mein start
                        # agar list empty bhi hota toh bhi new node ke prev mein none hota
                         # aur next mein start ka data jo ki agar node hoga toh uska address
                        # agar nahi hoga toh None aayega
     
    # basically ye 3 line upar likha gaya hai n ke andar dekho # n=Node(None,data,self.start) OK
    #  n.prev=None # n ke prev mein None hi hoga 
      #   n.item=data# n ke item mein data
     #   n.next=start # n ke next mein start jisko point karega wo agar kisi ko point nahi karega toh 
                   # bhi start mein None hoga ab wo none n yaani new node ke next mein aa jaaye 
                   # toh bhi koi dikkat nahi
       
        if not self.is_empty():# agar node empty nahi hai toh 
            self.start.prev=n # start ke prev mein naya node(n) ke address daal do 
                                 # tabhi toh wo jo pehle start ke baaad tha uske prev mein judega socho
                
        self.start=n # start mein new node(n) add kar do 
        # start if ke body ke bahar likha hai means ye dono  condition  mein work karegi 
        # 1.when there is only one node toh bhi kyunki ye if ki body mein nahi hai isliye chalega 
        # upar ka n wala logic aur self.start=n
        
        # 2. when there are more than one node yaani list empty nahi hai tab bhi tab wo if block mein aayega
        # aur start ke prev mein n rakhega aur start mein n rakhega  
        # start mein n rakhega kyunki wo if condtion toh nahi chalega but kyunki code up to down chalta hai
        # line by line wo self.start=n wale line mein aayega aur code 
        # chal jayega yani start mein n(new node) rakh dega

# %%
# 5.Insert at last

class Node:
    def __init__(self,prev,item,next):
        self.prev=prev
        self.item=item
        self.next=next
        
# Now class DLL
class DLL:
    def __init__(self,start=None):
        self.start=start
     
    
    def is_empty(self):
        return self.start==None # agar start mein none hai toh return karo  empty

    def insert_at_start(self,data):
        n=Node(None,data,self.start)# prev mein none , item mein data aur next mein start
                        # agar list empty bhi hota toh bhi new node ke prev mein none hota
                         # aur next mein start ka data jo ki agar node hoga toh uska address
                        # agar nahi hoga toh None aayega
     
    # basically ye 3 line upar likha gaya hai n ke andar dekho # n=Node(None,data,self.start) OK
    #  n.prev=None # n ke prev mein None hi hoga 
      #   n.item=data# n ke item mein data
     #   n.next=start # n ke next mein start jisko point karega wo agar kisi ko point nahi karega toh 
                   # bhi start mein None hoga ab wo none n yaani new node ke next mein aa jaaye 
                   # toh bhi koi dikkat nahi
       
        if not self.is_empty():# agar node empty nahi hai toh 
            self.start.prev=n # start ke prev mein naya node(n) ke address daal do
        self.start=n # start mein new node(n) add kar do 
        # start if ke body ke bahar likha hai means ye dono  condition  mein work karegi 
        # 1.when there is only one node toh bhi kyunki ye if ki body mein nahi hai isliye chalega 
        # upar ka n wala logic aur self.start=n
        
        # 2. when there are more than one node yaani list empty nahi hai tab bhi tab wo if block mein aayega
        # aur start ke prev mein n rakhega aur start mein n rakhega  
        # start mein n rakhega kyunki wo if condtion toh nahi chalega but kyunki code up to down chalta hai
        # line by line wo self.start=n wale line mein aayega aur code 
        # chal jayega yani start mein n(new node) rakh dega
        
        
        
     # solution here   
    def insert_at_last(self,data): # sirf data rakhna hai na
        temp=self.start # temp mein start rakhte hai 
                        # ye us case mein valid hoga jab node empty hoga tabhi toh temp mein start hoga
                        # agar link list mein multiple node honge toh temp mein start ki jagah
                        # temp mein last node ka address hoga jo ki neeche likkha hai logic while aur if mein
        
        
        # jab  node empty nahi hai tab
        if self.start!=None: # Agar start mein none nahi hai
            while temp.next!=None: # jab tak temp ke next mein None na aa jaye 
                                      # to find last node
                temp=temp.next  # temp ke andar temp ka next aata jaaye
                
        # creating new node
        n=Node(temp,data,None) # 1.prev mein temp 
                                        # aur ye if ke body ke bahar hai means dono ke liye 
                                       #chalega when list empty or not
                                     #  jab node empty hoga toh temp mein start hoga 
                                     # jab node empty nahi hoga tab temp mein last node ka 
                                       #address hoga (jo if se aa raha temp ka value)
                                            
                             # 2. item mein data aur 
                              #3.next mein none because ab ye last node ban ne wala hai
                               # no matter node empty ho ya nahi last mei toh None hi aayega
        
        # agar list empty hai tab temp mein               
        if temp==None: # agar temp mein none hai 
            self.start=n # start mein new node ko rakh do
            
        # agar list empty nahi hai tab
        else:  
            temp.next=n # temp ke next mein new node ko rakh do

# %%
# 6. Search item

class Node:
    def __init__(self,prev,item,next):
        self.prev=prev
        self.item=item
        self.next=next
        
# Now class DLL
class DLL:
    def __init__(self,start=None):
        self.start=start
     
    
    def is_empty(self):
        return self.start==None # agar start mein none hai toh return karo  empty

    def insert_at_start(self,data):
        n=Node(None,data,self.start)# prev mein none , item mein data aur next mein start
                        # agar list empty bhi hota toh bhi new node ke prev mein none hota
                         # aur next mein start ka data jo ki agar node hoga toh uska address
                        # agar nahi hoga toh None aayega
     
    # basically ye 3 line upar likha gaya hai n ke andar dekho # n=Node(None,data,self.start) OK
    #  n.prev=None # n ke prev mein None hi hoga 
      #   n.item=data# n ke item mein data
     #   n.next=start # n ke next mein start jisko point karega wo agar kisi ko point nahi karega toh 
                   # bhi start mein None hoga ab wo none n yaani new node ke next mein aa jaaye 
                   # toh bhi koi dikkat nahi
       
        if not self.is_empty():# agar node empty nahi hai toh 
            self.start.prev=n # start ke prev mein naya node(n) ke address daal do
        self.start=n # start mein new node(n) add kar do 
        # start if ke body ke bahar likha hai means ye dono  condition  mein work karegi 
        # 1.when there is only one node toh bhi kyunki ye if ki body mein nahi hai isliye chalega 
        # upar ka n wala logic aur self.start=n
        
        # 2. when there are more than one node yaani list empty nahi hai tab bhi tab wo if block mein aayega
        # aur start ke prev mein n rakhega aur start mein n rakhega  
        # start mein n rakhega kyunki wo if condtion toh nahi chalega but kyunki code up to down chalta hai
        # line by line wo self.start=n wale line mein aayega aur code 
        # chal jayega yani start mein n(new node) rakh dega
        
        
        
        
    def insert_at_last(self,data): # sirf data rakhna hai na
        temp=self.start # temp mein start rakhte hai 
                        # ye us case mein valid hoga jab node empty hoga tabhi toh temp mein start hoga
                        # agar link list mein multiple node honge toh temp mein start ki jagah
                        # temp mein last node ka address hoga jo ki neeche likkha hai logic while aur if mein
        
        
        # jab  node empty nahi hai tab
        if self.start!=None: # Agar start mein none nahi hai
            while temp.next!=None: # jab tak temp ke next mein None na aa jaye 
                                      # to find last node
                temp=temp.next  # temp ke andar temp ka next aata jaaye
                
        # creating new node
        n=Node(temp,data,None) # 1.prev mein temp 
                                        # aur ye if ke body ke bahar hai means dono ke liye 
                                       #chalega when list empty or not
                                     #  jab node empty hoga toh temp mein start hoga 
                                     # jab node empty nahi hoga tab temp mein last node ka 
                                       #address hoga (jo if se aa raha temp ka value)
                                            
                             # 2. item mein data aur 
                              #3.next mein none because ab ye last node ban ne wala hai
                               # no matter node empty ho ya nahi last mei toh None hi aayega
        
        # agar list empty hai tab temp mein               
        if temp==None: # agar temp mein none hai 
            self.start=n # start mein new node ko rakh do
            
        # agar list empty nahi hai tab
        else:  
            temp.next=n # temp ke next mein new node ko rakh do
      
    
    # solution here
    def search(self,data): # item hi search karoge na
        temp=self.start
        while temp is not None: # jab tak last node tak na pahuch jaaye
            if temp.item==data: # agar temp ke item data ke barabaar hai toh data mil gaya
                return temp  # toh return kar do temp yani data
            temp=temp.next # nahi toh aage check karo
        return None # pura node check karne par bhi node nahi mila toh None return karo
                     # that's why return while loop ke bahar hai\
                        # aur agar list empty bhi hai toh bhi None return kar do becuase us condition 
                        # mein while loop mein enter hi nahi karega toh return none karega hi us time 
                # bhi ye line return none  beneficial hoga

# %%
# 7.Insert after

class Node:
    def __init__(self,prev,item,next):
        self.prev=prev
        self.item=item
        self.next=next
        
# Now class DLL
class DLL:
    def __init__(self,start=None):
        self.start=start
        
    def is_empty(self):
        return self.start==None # agar start mein none hai toh return karo  empty

    def insert_at_start(self,data):
        n=Node(None,data)# prev mein none , item mein data aur next mein start
                        # agar list empty bhi hota toh bhi new node ke prev mein none hota
                         # aur next mein start ka data jo ki agar node hoga toh uska address
                         # agar nahi hoga toh None aayega
                
        if not self.is_empty():# agar node empty nahi hai toh 
            self.start.prev=n # start ke prev mein naya node(n) ke address daal do
        self.start=n # start mein new node(n) add kar do
        
        
        
    def insert_at_last(self,data): # sirf data rakhna hai na
        if self.start!=None: # Agar start mein none nahi hai
                           # jab  node empty nahi hai tab

            while temp.next!=None: # jab tak temp ke next mein None na aa jaye 
                                      # to find last node
                tem=temp.next  # temp ke andar temp ka next aata jaaye
                
        # creating new node
        n=Node(temp,data,None) # prev mein temp yaani pehle wala last node ka address
                             # item mein data aur next mein none because ab ye last node ban ne wala hai
        if temp==None: # agar temp mein none hai 
                         # means list empty hai tab
            self.start=n
        else:  # agar list empty nahi hai tab
            temp.next=n
        
    def search(self,data): # item hi search karoge na
        temp=self.start
        while temp is not None: # jab tak last node tak na pahuch jaaye
            if temp.item==data: # agar temp ke item data ke barabaar hai toh data mil gaya
                return temp  # toh return kar do temp yani data
            temp=temp.next # nahi toh aage check karo
        return None # pura node check karne par bhi node nahi mila toh None return karo
                     # that's why return while loop ke bahar hai\
                        # aur agar list empty bhi hai toh bhi None return kar do becuase us condition 
                        # mein while loop mein enter hi nahi karega toh return none karega hi us time 
                # bhi ye line return none  beneficial hoga
                
        
        
# Solution here
    def insert_after(self,temp,data):# kisi node ke baad hi data daaloge na jo temp hai, data jo daalna
        if temp is not None: # agar node empty nahi hai tab  socho agar temp none hoga tab kaise data daloge
                         # kyunki data kisi do node ke beech mein hi dalna hoga toh list mein 
                            # atleast 1 node toh hoga tab hi toh uske beech mein data dalenge
            n=Node(temp,data,temp.next) # prev mein temp rakhenge, item mein data, next mein temp ka next
                                            # next mein temp ka next isliye rakhenge kyunki 
                                            # temp us node ko point karega jo node ke beech mein data rakhenge
                                            # aur temp.next mein wo data hoga jisko temp point kar raha hoga
                                            # uska next ka value toh socho humko new node temp ke beech mein
                                            # rakhna hai na toh new node ke next mein temp ka next hoga
            
            # lekin agar akhiri node ke beech mein data insert kar rahe tab check karo
            if temp.next is not None: # temp ka next none nahi hai 
                temp.next.prev=n # temp ke next ke prev mein new node rakh do
             
            # lekin agar akhiri node ke beech data ho tab 
            # temp jisko point kar raha wo akhiri node ho tab
            temp.next=n   # temp ka next mein new node rakh do

# %%
# 8.Print all elements

class Node:
    def __init__(self,prev,item,next):
        self.prev=prev
        self.item=item
        self.next=next
        
# Now class DLL
class DLL:
    def __init__(self,start=None):
        self.start=start
        
    def is_empty(self):
        return self.start==None # agar start mein none hai toh return karo  empty

    def insert_at_start(self,data):
        n=Node(None,data)# prev mein none , item mein data aur next mein start
                        # agar list empty bhi hota toh bhi new node ke prev mein none hota
                         # aur next mein start ka data jo ki agar node hoga toh uska address
                         # agar nahi hoga toh None aayega
                
        if not self.is_empty():# agar node empty nahi hai toh 
            self.start.prev=n # start ke prev mein naya node(n) ke address daal do
        self.start=n # start mein new node(n) add kar do
        
        
        
    def insert_at_last(self,data): # sirf data rakhna hai na
        if self.start!=None: # Agar start mein none nahi hai
                           # jab  node empty nahi hai tab

            while temp.next!=None: # jab tak temp ke next mein None na aa jaye 
                                      # to find last node
                tem=temp.next  # temp ke andar temp ka next aata jaaye
                
        # creating new node
        n=Node(temp,data,None) # prev mein temp yaani pehle wala last node ka address
                             # item mein data aur next mein none because ab ye last node ban ne wala hai
        if temp==None: # agar temp mein none hai 
                         # means list empty hai tab
            self.start=n
        else:  # agar list empty nahi hai tab
            temp.next=n
        
    def search(self,data): # item hi search karoge na
        temp=self.start
        while temp is not None: # jab tak last node tak na pahuch jaaye
            if temp.item==data: # agar temp ke item data ke barabaar hai toh data mil gaya
                return temp  # toh return kar do temp yani data
            temp=temp.next # nahi toh aage check karo
        return None # pura node check karne par bhi node nahi mila toh None return karo
                     # that's why return while loop ke bahar hai\
                        # aur agar list empty bhi hai toh bhi None return kar do becuase us condition 
                        # mein while loop mein enter hi nahi karega toh return none karega hi us time 
                # bhi ye line return none  beneficial hoga
                
        
        

    def insert_after(self,temp,data):# kisi node ke baad hi data daaloge na jo temp hai, data jo daalna
        if temp is not None: # agar node empty nahi hai tab 
            n=Node(temp,data,temp.next) # temp rakhenge, data, temp ka next
            if temp.next is not None: # 
                temp.next.prev=n
                
            temp.next=n 
            
            
# Solution here

    def print_list(self): # sirf print karna hai toh isliye kuch nahi aaya argument 
        temp=self.start   # temp mein shuru mein start ka reference diye 
        while temp is not None: # check karta rahe last node tak becuase last node ke next mein none hota hai
            print(temp.item,end=" ") # print karta jaaye temp ke item ko
            temp=temp.next # har baar aage badhata jaaye

# %%
# 9. Delete First

# 8.Print all elements

class Node:
    def __init__(self,prev,item,next):
        self.prev=prev
        self.item=item
        self.next=next
        
# Now class DLL
class DLL:
    def __init__(self,start=None):
        self.start=start
        
    def is_empty(self):
        return self.start==None # agar start mein none hai toh return karo  empty

    def insert_at_start(self,data):
        n=Node(None,data)# prev mein none , item mein data aur next mein start
                        # agar list empty bhi hota toh bhi new node ke prev mein none hota
                         # aur next mein start ka data jo ki agar node hoga toh uska address
                         # agar nahi hoga toh None aayega
                
        if not self.is_empty():# agar node empty nahi hai toh 
            self.start.prev=n # start ke prev mein naya node(n) ke address daal do
        self.start=n # start mein new node(n) add kar do
        
        
        
    def insert_at_last(self,data): # sirf data rakhna hai na
        if self.start!=None: # Agar start mein none nahi hai
                           # jab  node empty nahi hai tab

            while temp.next!=None: # jab tak temp ke next mein None na aa jaye 
                                      # to find last node
                tem=temp.next  # temp ke andar temp ka next aata jaaye
                
        # creating new node
        n=Node(temp,data,None) # prev mein temp yaani pehle wala last node ka address
                             # item mein data aur next mein none because ab ye last node ban ne wala hai
        if temp==None: # agar temp mein none hai 
                         # means list empty hai tab
            self.start=n
        else:  # agar list empty nahi hai tab
            temp.next=n
        
    def search(self,data): # item hi search karoge na
        temp=self.start
        while temp is not None: # jab tak last node tak na pahuch jaaye
            if temp.item==data: # agar temp ke item data ke barabaar hai toh data mil gaya
                return temp  # toh return kar do temp yani data
            temp=temp.next # nahi toh aage check karo
        return None # pura node check karne par bhi node nahi mila toh None return karo
                     # that's why return while loop ke bahar hai\
                        # aur agar list empty bhi hai toh bhi None return kar do becuase us condition 
                        # mein while loop mein enter hi nahi karega toh return none karega hi us time 
                # bhi ye line return none  beneficial hoga
                
        
        

    def insert_after(self,temp,data):# kisi node ke baad hi data daaloge na jo temp hai, data jo daalna
        if temp is not None: # agar node empty nahi hai tab 
            n=Node(temp,data,temp.next) # temp rakhenge, data, temp ka next
            if temp.next is not None: # 
                temp.next.prev=n
                
            temp.next=n 
            
    def print_list(self): # sirf print karna hai toh isliye kuch nahi aaya argument 
        temp=self.start   # temp mein shuru mein start ka reference diye 
        while temp is not None: # check karta rahe last node tak becuase last node ke next mein none hota hai
            print(temp.item,end=" ") # print karta jaaye temp ke item ko
            temp=temp.next # har baar aage badhata jaaye
            
    
    
    # Solution here   
    def delete_first(self):
        if self.start is not None: # agar node empty nahi hai tab
            self.start=self.start.next # start mein start ka next 
                            # start mein durse wale node ka referenece agar dursra node nahi hai toh none aa jaye
                
                 # yaani agar list mein ek node hua toh ya uske baad  node hai ya nahi check in next line
            if self.start is not None: # agar ab start mein none nahi hua means node mein ek se jyada node hai
                self.start.prev=None # start ke prev mein None daal do kyunki ab ye first node bangega 
                                                        # aur first node ke prev mein none hi hota hai

# %%
# 9. Delete last

class Node:
    def __init__(self,prev,item,next):
        self.prev=prev
        self.item=item
        self.next=next
        
# Now class DLL
class DLL:
    def __init__(self,start=None):
        self.start=start
        
    def is_empty(self):
        return self.start==None # agar start mein none hai toh return karo  empty

    def insert_at_start(self,data):
        n=Node(None,data)# prev mein none , item mein data aur next mein start
                        # agar list empty bhi hota toh bhi new node ke prev mein none hota
                         # aur next mein start ka data jo ki agar node hoga toh uska address
                         # agar nahi hoga toh None aayega
                
        if not self.is_empty():# agar node empty nahi hai toh 
            self.start.prev=n # start ke prev mein naya node(n) ke address daal do
        self.start=n # start mein new node(n) add kar do
        
        
        
    def insert_at_last(self,data): # sirf data rakhna hai na
        if self.start!=None: # Agar start mein none nahi hai
                           # jab  node empty nahi hai tab

            while temp.next!=None: # jab tak temp ke next mein None na aa jaye 
                                      # to find last node
                tem=temp.next  # temp ke andar temp ka next aata jaaye
                
        # creating new node
        n=Node(temp,data,None) # prev mein temp yaani pehle wala last node ka address
                             # item mein data aur next mein none because ab ye last node ban ne wala hai
        if temp==None: # agar temp mein none hai 
                         # means list empty hai tab
            self.start=n
        else:  # agar list empty nahi hai tab
            temp.next=n
        
    def search(self,data): # item hi search karoge na
        temp=self.start
        while temp is not None: # jab tak last node tak na pahuch jaaye
            if temp.item==data: # agar temp ke item data ke barabaar hai toh data mil gaya
                return temp  # toh return kar do temp yani data
            temp=temp.next # nahi toh aage check karo
        return None # pura node check karne par bhi node nahi mila toh None return karo
                     # that's why return while loop ke bahar hai\
                        # aur agar list empty bhi hai toh bhi None return kar do becuase us condition 
                        # mein while loop mein enter hi nahi karega toh return none karega hi us time 
                # bhi ye line return none  beneficial hoga
                
        
        

    def insert_after(self,temp,data):# kisi node ke baad hi data daaloge na jo temp hai, data jo daalna
        if temp is not None: # agar node empty nahi hai tab 
            n=Node(temp,data,temp.next) # temp rakhenge, data, temp ka next
            if temp.next is not None: # 
                temp.next.prev=n
                
            temp.next=n 
            
    def print_list(self): # sirf print karna hai toh isliye kuch nahi aaya argument 
        temp=self.start   # temp mein shuru mein start ka reference diye 
        while temp is not None: # check karta rahe last node tak becuase last node ke next mein none hota hai
            print(temp.item,end=" ") # print karta jaaye temp ke item ko
            temp=temp.next # har baar aage badhata jaaye
            
    
  
    def delete_first(self):
        if self.start is not None: # agar node empty nahi hai tab
            self.start=self.start.next # start mein start ka next 
                            # start mein durse wale node ka referenece agar dursra node nahi hai toh none aa jaye
                
                 # yaani agar list mein ek node hua toh ya uske baad  node hai ya nahi check in next line
            if self.start is not None: # agar ab start mein none nahi hua means node mein ek se jyada node hai
                self.start.prev=None # start ke prev mein None daal do kyunki ab ye first node bangega 
                                                        # aur first node ke prev mein none hi hota hai
            
    
    # Solution here 
    def delete_last(self):
        
        # agar list mein ek bhi node nahi hai tab
        if self.start is  None: # agar list empty  hai tab
            pass
        
        # agar list mein ek hi node hai tab
        elif self.start.next is None: # start ka next none yaani list mein ek hi node hai tab
            self.start=None # toh start mein none rakh do ho gaya pehla node delete
            
         # agar list mein ek se jyada ya multiple nodes huwe tab   
        else:
            temp=self.start
            while self.start is not None: 
                temp=temp.next
            temp.prev.next=None # temp ke prev ke next mein None 
            # temp last node tak chala loop se toh is hisab se temp ke previous node ke next yaani 
            # last node ke next mein None rakh do  toh ho gaya na last node delete CONGRATULATIONS Bhai

# %%
# 10. Delete item

class Node:
    def __init__(self,prev,item,next):
        self.prev=prev
        self.item=item
        self.next=next
        
# Now class DLL
class DLL:
    def __init__(self,start=None):
        self.start=start
        
    def is_empty(self):
        return self.start==None # agar start mein none hai toh return karo  empty

    def insert_at_start(self,data):
        n=Node(None,data)# prev mein none , item mein data aur next mein start
                        # agar list empty bhi hota toh bhi new node ke prev mein none hota
                         # aur next mein start ka data jo ki agar node hoga toh uska address
                         # agar nahi hoga toh None aayega
                
        if not self.is_empty():# agar node empty nahi hai toh 
            self.start.prev=n # start ke prev mein naya node(n) ke address daal do
        self.start=n # start mein new node(n) add kar do
        
        
        
    def insert_at_last(self,data): # sirf data rakhna hai na
        if self.start!=None: # Agar start mein none nahi hai
                           # jab  node empty nahi hai tab

            while temp.next!=None: # jab tak temp ke next mein None na aa jaye 
                                      # to find last node
                tem=temp.next  # temp ke andar temp ka next aata jaaye
                
        # creating new node
        n=Node(temp,data,None) # prev mein temp yaani pehle wala last node ka address
                             # item mein data aur next mein none because ab ye last node ban ne wala hai
        if temp==None: # agar temp mein none hai 
                         # means list empty hai tab
            self.start=n
        else:  # agar list empty nahi hai tab
            temp.next=n
        
    def search(self,data): # item hi search karoge na
        temp=self.start
        while temp is not None: # jab tak last node tak na pahuch jaaye
            if temp.item==data: # agar temp ke item data ke barabaar hai toh data mil gaya
                return temp  # toh return kar do temp yani data
            temp=temp.next # nahi toh aage check karo
        return None # pura node check karne par bhi node nahi mila toh None return karo
                     # that's why return while loop ke bahar hai\
                        # aur agar list empty bhi hai toh bhi None return kar do becuase us condition 
                        # mein while loop mein enter hi nahi karega toh return none karega hi us time 
                # bhi ye line return none  beneficial hoga
                
        
        

    def insert_after(self,temp,data):# kisi node ke baad hi data daaloge na jo temp hai, data jo daalna
        if temp is not None: # agar node empty nahi hai tab 
            n=Node(temp,data,temp.next) # temp rakhenge, data, temp ka next
            if temp.next is not None: # 
                temp.next.prev=n
                
            temp.next=n 
            
    def print_list(self): # sirf print karna hai toh isliye kuch nahi aaya argument 
        temp=self.start   # temp mein shuru mein start ka reference diye 
        while temp is not None: # check karta rahe last node tak becuase last node ke next mein none hota hai
            print(temp.item,end=" ") # print karta jaaye temp ke item ko
            temp=temp.next # har baar aage badhata jaaye
            
    
  
    def delete_first(self):
        if self.start is not None: # agar node empty nahi hai tab
            self.start=self.start.next # start mein start ka next 
                            # start mein durse wale node ka referenece agar dursra node nahi hai toh none aa jaye
                
                 # yaani agar list mein ek node hua toh ya uske baad  node hai ya nahi check in next line
            if self.start is not None: # agar ab start mein none nahi hua means node mein ek se jyada node hai
                self.start.prev=None # start ke prev mein None daal do kyunki ab ye first node bangega 
                                                        # aur first node ke prev mein none hi hota hai
            
    
    
    def delete_last(self):
        
        # agar list mein ek bhi node nahi hai tab
        if self.start is  None: # agar list empty  hai tab
            pass
        
        # agar list mein ek hi node hai tab
        elif self.start.next is None: # start ka next none yaani list mein ek hi node hai tab
            self.start=None # toh start mein none rakh do ho gaya pehla node delete
            
         # agar list mein ek se jyada ya multiple nodes huwe tab   
        else:
            temp=self.start
            while self.start is not None: 
                temp=temp.next
            temp.prev.next=None # temp ke prev ke next mein None 
            # temp last node tak chala loop se toh is hisab se temp ke previous node ke next yaani 
            # last node ke next mein None rakh do  toh ho gaya na last node delete CONGRATULATIONS Bhai

            
    # Solution here 
    def delete_item():
       
    # agar list mein ek bhi node nahi hai toh pass kar jaao
        if self.start is None:
            pass
        

# ye pehla node ko delete karne ka kaam kar rahi thi but ab wo else wala part hi kar de raha
# *****************************No Need********************************************************
#         # Agar list mei ek node hai tab
#         elif self.start.next is None: # agar start ke next wala none hai yaani list mein ek hi node hai tab
#             if self.start.item == temp: # aur ek node jo hai uska item aur data match kar jaaye toh
#                 self.start=None # start mein none rakh do yaani ho gaya wo delete
# **************************************No need********************************************************


    # agar ek ya ek se jyada nodes ho ya multiple node ho tab
        # else:
        #     temp=self.start
            
# ye pehla node ko delete karne ka kaam kar rahi thi but ab wo else wala part hi kar de raha            
# *****************************No Need********************************************************
#             #agar pehla node match kar jaaye data se
#             if temp.item==data: 
#                     self.start=temp.next # start mein temp ka next yaani dursa node ka address
#                     temp.next.prev=None # temp ka next ka prev yaani (2nd node ka prev) mein None 
# *****************************No Need********************************************************
        else:
            temp=self.start # temp mein start rakhe aur 
            while temp is not None : # jab tak temp mein none nahi aa jata tab tak traverse kare
                if temp.item==data: # temp ke item aur data barabar ho toh
                    
                    if temp.next is not None: # temp ke aage wala node empty na ho 
                        temp.next.prev=temp.prev # temp ke next ke prev(temp ke age wala node ka prev) 
                                            #temp ka prev(temp ka pichla node ka prev) daal do
                    
                    # do baar if yaani dono check kare kahi ye conditon toh fail nahi hai
                    if temp.prev is not None: # temp ka prev start na ho 
                        temp.prev.next=temp.next # aru temp ke prev ke next (temp ke pichla node ke next) mein
                                                # temp ka next(temp ke next node ka reference ) daal do matlab 
                                                # ab node jud gaya 
                        
                    else: # agar temp ka prev start hua toh
                        self.start=temp.next # start mei temp ka next
                    
                    break # ksii se bhi match kiya toh break otherwise
               
                temp=temp.next    # temp mein temp ka next yaani aage check karo

# %%
# 11. Iterator

class Node:
    def __init__(self,prev=None,item=None,next=None):
        self.prev=prev
        self.item=item
        self.next=next
        
# Now class DLL
class DLL:
    def __init__(self,start=None):
        self.start=start
        
    def is_empty(self):
        return self.start==None # agar start mein none hai toh return karo  empty

    def insert_at_start(self,data):
        n=Node(None,data,self.start)# prev mein none , item mein data aur next mein start
                        # agar list empty bhi hota toh bhi new node ke prev mein none hota
                         # aur next mein start ka data jo ki agar node hoga toh uska address
                         # agar nahi hoga toh None aayega
                
        if not self.is_empty():# agar node empty nahi hai toh 
            self.start.prev=n # start ke prev mein naya node(n) ke address daal do
        self.start=n # start mein new node(n) add kar do
        
        
        
    def insert_at_last(self,data): # sirf data rakhna hai na
        temp=self.start # temp mein start 
        
        if self.start!=None: # Agar start mein none nahi hai
                           # jab  node empty nahi hai tab
            
            while temp.next!=None: # jab tak temp ke next mein None na aa jaye 
                                      # to find last node
                temp=temp.next  # temp ke andar temp ka next aata jaaye
                
        # creating new node
        n=Node(temp,data,None) # prev mein temp yaani pehle wala last node ka address
                             # item mein data aur next mein none because ab ye last node ban ne wala hai
        if temp==None: # agar temp mein none hai 
                         # means list empty hai tab
            self.start=n
        else:  # agar list empty nahi hai tab
            temp.next=n
        
    def search(self,data): # item hi search karoge na
        temp=self.start
        while temp is not None: # jab tak last node tak na pahuch jaaye
            if temp.item==data: # agar temp ke item data ke barabaar hai toh data mil gaya
                return temp  # toh return kar do temp yani data
            temp=temp.next # nahi toh aage check karo
        return None # pura node check karne par bhi node nahi mila toh None return karo
                     # that's why return while loop ke bahar hai\
                        # aur agar list empty bhi hai toh bhi None return kar do becuase us condition 
                        # mein while loop mein enter hi nahi karega toh return none karega hi us time 
                # bhi ye line return none  beneficial hoga
                
        
        

    def insert_after(self,temp,data):# kisi node ke baad hi data daaloge na jo temp hai, data jo daalna
        if temp is not None: # agar node empty nahi hai tab 
            n=Node(temp,data,temp.next) # temp rakhenge, data, temp ka next
            if temp.next is not None: # 
                temp.next.prev=n
                
            temp.next=n 
            
    def print_list(self): # sirf print karna hai toh isliye kuch nahi aaya argument 
        temp=self.start   # temp mein shuru mein start ka reference diye 
        while temp is not None: # check karta rahe last node tak becuase last node ke next mein none hota hai
            print(temp.item,end=" ") # print karta jaaye temp ke item ko
            temp=temp.next # har baar aage badhata jaaye
            
    
  
    def delete_first(self):
        if self.start is not None: # agar node empty nahi hai tab
            self.start=self.start.next # start mein start ka next 
                            # start mein durse wale node ka referenece agar dursra node nahi hai toh none aa jaye
                
                 # yaani agar list mein ek node hua toh ya uske baad  node hai ya nahi check in next line
            if self.start is not None: # agar ab start mein none nahi hua means node mein ek se jyada node hai
                self.start.prev=None # start ke prev mein None daal do kyunki ab ye first node bangega 
                                                        # aur first node ke prev mein none hi hota hai
            
    
    
    def delete_last(self):
        
        # agar list mein ek bhi node nahi hai tab
        if self.start is  None: # agar list empty  hai tab
            pass
        
        # agar list mein ek hi node hai tab
        elif self.start.next is None: # start ka next none yaani list mein ek hi node hai tab
            self.start=None # toh start mein none rakh do ho gaya pehla node delete
            
         # agar list mein ek se jyada ya multiple nodes huwe tab   
        else:
            temp=self.start
            while temp is not None: 
                temp=temp.next
            temp.prev.next=None # temp ke prev ke next mein None 
            # temp last node tak chala loop se toh is hisab se temp ke previous node ke next yaani 
            # last node ke next mein None rakh do  toh ho gaya na last node delete CONGRATULATIONS Bhai

             
    def delete_item():
       
    # agar list mein ek bhi node nahi hai toh pass kar jaao
        if self.start is None:
            pass
        

# ye pehla node ko delete karne ka kaam kar rahi thi but ab wo else wala part hi kar de raha
# *****************************No Need********************************************************
#         # Agar list mei ek node hai tab
#         elif self.start.next is None: # agar start ke next wala none hai yaani list mein ek hi node hai tab
#             if self.start.item == temp: # aur ek node jo hai uska item aur data match kar jaaye toh
#                 self.start=None # start mein none rakh do yaani ho gaya wo delete
# **************************************No need********************************************************


    # agar ek ya ek se jyada nodes ho ya multiple node ho tab
        # else:
        #     temp=self.start
            
# ye pehla node ko delete karne ka kaam kar rahi thi but ab wo else wala part hi kar de raha            
# *****************************No Need********************************************************
#             #agar pehla node match kar jaaye data se
#             if temp.item==data: 
#                     self.start=temp.next # start mein temp ka next yaani dursa node ka address
#                     temp.next.prev=None # temp ka next ka prev yaani (2nd node ka prev) mein None 
# *****************************No Need********************************************************
        else:
            temp=self.start # temp mein start rakhe aur 
            while temp is not None : # jab tak temp mein none nahi aa jata tab tak traverse kare
                if temp.item==data: # temp ke item aur data barabar ho toh
                    
                    if temp.next is not None: # temp ke aage wala node empty na ho 
                        temp.next.prev=temp.prev # temp ke next ke prev(temp ke age wala node ka prev) 
                                            #temp ka prev(temp ka pichla node ka prev) daal do
                    
                    # do baar if yaani dono check kare kahi ye conditon toh fail nahi hai
                    if temp.prev is not None: # temp ka prev start na ho 
                        temp.prev.next=temp.next # aru temp ke prev ke next (temp ke pichla node ke next) mein
                                                # temp ka next(temp ke next node ka reference ) daal do matlab 
                                                # ab node jud gaya 
                        
                    else: # agar temp ka prev start hua toh
                        self.start=temp.next # start mei temp ka next
                    
                    break # ksii se bhi match kiya toh break otherwise
               
                temp=temp.next    # temp mein temp ka next yaani aage check karo            
     
    
    
   # Solution here
    def __iter__(self): # ek function banao __iter__ tabhi iterable banega
        return DLLIterator(self.start) # aur SLLIterator ko return kar do start se  (start upar wala start hai yaani shuru se list ko chala do end tak)
    
class DLLIterator: # pehle class iterable banana hoga 
    def __init__(self,start): # phir function start se shrur karenge
        self.current=start # current mein start rakh denge # current work as temp jaise kaam karta tha
        
    def __iter__(self): # phir __iter__ banayenge
        return self      # self return karayenge 
    
    def __next__(self): # phir next 
        if not self.current: # agar nahi hai current mein 
            raise StopIteration # iteration rok do message aa jaye ye exception handling mein padha tha na
        data=self.current.item  # current ke item  ko data mein rakh do (just like temp ke item ko)
        self.current=self.current.next  # current mein current ka next(just like temp mein temp.next)
        return data
            
        

mylist=DLL()
mylist.insert_at_start(10)
mylist.insert_at_last(20)
mylist.insert_at_last(30)
mylist.insert_after(mylist.search(10),15)
mylist.print_list()
mylist.delete_first()
print()
mylist.print_list()
mylist.delete_last()

for x in mylist:
    print(x)
# Out:
# 10 15 20 30
# 15 20 30
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[23], line 191
#     189 print()
#     190 mylist.print_list()
# --> 191 mylist.delete_last()
#     193 for x in mylist:
#     194     print(x)
#
# Cell In[23], line 106, in DLL.delete_last(self)
#     104 while temp is not None:
#     105     temp=temp.next
# --> 106 temp.prev.next=None
#
# AttributeError: 'NoneType' object has no attribute 'prev'
