# %%
class Node():
    def __init__(self,item=None,prev=None,next=None):
        self.prev=prev
        self.next=next

class Deque():
    def __init__(self):
        self.front=None
        self.rear=None
        self.item_count=0

# %%
class Node():
    def __init__(self,item=None,prev=None,next=None):
        self.prev=prev
        self.next=next

class Deque():
    def __init__(self):
        self.front=None
        self.rear=None
        self.item_count=0
        
    def is_empty(self):
        return self.item_count==0
        # return self.front==None
        # return self.front==None

# %%
class Node():
    def __init__(self,item=None,prev=None,next=None):
        self.prev=prev
        self.next=next

class Deque():
    def __init__(self):
        self.front=None
        self.rear=None
        self.item_count=0
        
    def is_empty(self):
        return self.item_count==0
        # return self.front==None
        # return self.front==None
    
    def insert_front(self,data):
        n=Node(data,None,self.front)
        if self.is_empty():
            self.rear=n
        else:
            self.front.prev=n
            
        self.front=n # front mein new node dono case mein aayega empty or multiple nodes
        self.item_count+=1

# %%
class Node():
    def __init__(self,item=None,prev=None,next=None):
        self.prev=prev
        self.next=next

class Deque():
    def __init__(self):
        self.front=None
        self.rear=None
        self.item_count=0
        
    def is_empty(self):
        return self.item_count==0
        # return self.front==None
        # return self.front==None
    
    def insert_front(self,data):
        n=Node(data,None,self.front)
        if self.is_empty():
            self.rear=n
        else:
            self.front.prev=n
            
        self.front=n # front mein new node dono case mein aayega empty or multiple nodes
        self.item_count+=1 
    
    def insert_rear(self,data):
        n=Node(data,self.rear,None) # rear mein new node jodne ke liye rear ke prev mein purana rear 
                                    # aur next mein None but no need to write next automatically none ho jayega
        if self.is_empty():
            self.front=n
        else:
            self.rear.next=n
            
        self.rear=n # rear mein new node dono case mein aayega empty or multiple nodes
        self.item_count+=1

# %%
class Node():
    def __init__(self,item=None,prev=None,next=None):
        self.prev=prev
        self.next=next

class Deque():
    def __init__(self):
        self.front=None
        self.rear=None
        self.item_count=0
        
    def is_empty(self):
        return self.item_count==0
        # return self.front==None
        # return self.front==None
    
    def insert_front(self,data):
        n=Node(data,None,self.front)
        if self.is_empty():
            self.rear=n
        else:
            self.front.prev=n
            
        self.front=n # front mein new node dono case mein aayega empty or multiple nodes
        self.item_count+=1 
    
    def insert_rear(self,data):
        n=Node(data,self.rear,None) # rear mein new node jodne ke liye rear ke prev mein purana rear 
                                    # aur next mein None but no need to write next automatically none ho jayega
        if self.is_empty():
            self.front=n
        else:
            self.rear.next=n
            
        self.rear=n # rear mein new node dono case mein aayega empty or multiple nodes
        self.item_count+=1 
        
    def delete_front(self):
        if self.is_empty():
            raise IndexError("Deque is empty")
        #agar list mein ek hi node hai toh
        if self.front==self.rear:
            self.front=None
            self.rear=None
        #agar list mein multiple node hai toh
        else:
            self.front=self.front.next
            self.front.prev=None # 2nd node ke prev mein None
        self.item_count-=1
            
    def delete_rear(self):
        if self.is_empty():
            raise IndexError("Deque is empty")
        #agar list mein ek hi node hai toh
        if self.front==self.rear:
            self.front=None
            self.rear=None
        #agar list mein multiple node hai toh
        else:
            self.rear=self.rear.prev # rear mein rear ka prev
            self.rear.next=None # new rear jo bana uske next mein None
        self.item_count-=1

# %%
class Node():
    def __init__(self,item=None,prev=None,next=None):
        self.prev=prev
        self.next=next

class Deque():
    def __init__(self):
        self.front=None
        self.rear=None
        self.item_count=0
        
    def is_empty(self):
        return self.item_count==0
        # return self.front==None
        # return self.front==None
    
    def insert_front(self,data):
        n=Node(data,None,self.front)
        if self.is_empty():
            self.rear=n
        else:
            self.front.prev=n
            
        self.front=n # front mein new node dono case mein aayega empty or multiple nodes
        self.item_count+=1 
    
    def insert_rear(self,data):
        n=Node(data,self.rear,None) # rear mein new node jodne ke liye rear ke prev mein purana rear 
                                    # aur next mein None but no need to write next automatically none ho jayega
        if self.is_empty():
            self.front=n
        else:
            self.rear.next=n
            
        self.rear=n # rear mein new node dono case mein aayega empty or multiple nodes
        self.item_count+=1 
        
    def delete_front(self):
        if self.is_empty():
            raise IndexError("Deque is empty")
        #agar list mein ek hi node hai toh
        if self.front==self.rear:
            self.front=None
            self.rear=None
        #agar list mein multiple node hai toh
        else:
            self.front=self.front.next
            self.front.prev=None # 2nd node ke prev mein None
        self.item_count-=1
            
    def delete_rear(self):
        if self.is_empty():
            raise IndexError("Deque is empty")
        #agar list mein ek hi node hai toh
        if self.front==self.rear:
            self.front=None
            self.rear=None
        #agar list mein multiple node hai toh
        else:
            self.rear=self.rear.prev # rear mein rear ka prev
            self.rear.next=None # new rear jo bana uske next mein None
        self.item_count-=1
        
            
    def get_front(self):
        if self.is_empty():
            raise IndexError("Deque is empty")
        else:
            return self.front.item
    def get_rear(self):
        if self.is_emtpy():
            raise IndexError("Deque is empty")
        else:
            return self.rear.item

# %%
class Node():
    def __init__(self,item=None,prev=None,next=None):
        self.prev=prev
        self.next=next

class Deque():
    def __init__(self):
        self.front=None
        self.rear=None
        self.item_count=0
        
    def is_empty(self):
        return self.item_count==0
        # return self.front==None
        # return self.front==None
    
    def insert_front(self,data):
        n=Node(data,None,self.front)
        if self.is_empty():
            self.rear=n
        else:
            self.front.prev=n
            
        self.front=n # front mein new node dono case mein aayega empty or multiple nodes
        self.item_count+=1 
    
    def insert_rear(self,data):
        n=Node(data,self.rear,None) # rear mein new node jodne ke liye rear ke prev mein purana rear 
                                    # aur next mein None but no need to write next automatically none ho jayega
        if self.is_empty():
            self.front=n
        else:
            self.rear.next=n
            
        self.rear=n # rear mein new node dono case mein aayega empty or multiple nodes
        self.item_count+=1 
        
    def delete_front(self):
        if self.is_empty():
            raise IndexError("Deque is empty")
        #agar list mein ek hi node hai toh
        if self.front==self.rear:
            self.front=None
            self.rear=None
        #agar list mein multiple node hai toh
        else:
            self.front=self.front.next
            self.front.prev=None # 2nd node ke prev mein None
        self.item_count-=1
            
    def delete_rear(self):
        if self.is_empty():
            raise IndexError("Deque is empty")
        #agar list mein ek hi node hai toh
        if self.front==self.rear:
            self.front=None
            self.rear=None
        #agar list mein multiple node hai toh
        else:
            self.rear=self.rear.prev # rear mein rear ka prev
            self.rear.next=None # new rear jo bana uske next mein None
        self.item_count-=1
        
            
    def get_front(self):
        if self.is_empty():
            raise IndexError("Deque is empty")
        else:
            return self.front.item
    def get_rear(self):
        if self.is_emtpy():
            raise IndexError("Deque is empty")
        else:
            return self.rear.item
    
    def size(self):
        return self.item_count
    
d1=Deque()
d1.insert_front(10)
d1.insert_front(20)
d1.insert_rear(30)
d1.insert_rear(40)
print(d1.get_front(),d1.get_rear())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[18], line 84
#      82 d1.insert_rear(30)
#      83 d1.insert_rear(40)
# ---> 84 print(d1.get_front(),d1.get_rear())
#
# Cell In[18], line 69, in Deque.get_front(self)
#      67     raise IndexError("Deque is empty")
#      68 else:
# ---> 69     return self.front.item
#
# AttributeError: 'Node' object has no attribute 'item'
